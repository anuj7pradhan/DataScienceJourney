# %% [markdown]
# Lecture 6

# %% [markdown]
# Revision of lec 1 - 5

# %% [markdown]
# LECTURE 1 - 5
# Fundamentals of data science and python
# Variables and data types
# operators in python
# Built in Functions

# %% [markdown]
# You are developing a program for a math competition  where  participants need to solve mathematical expressions and provide the result. You want to use Python to automate the evaluation process. Here's how you could approach it:
#
# 1) Take input from the participants to enter a mathematical expression
# 2) Evaluate the expression entered by the participant and obtain the result
# 3) Display the result to the participant.

# %%
mathematical_expression = input("Enter the mathematical expression")
result = eval(mathematical_expression)
print("Your result is", result)
print("Thank you")
# Out:
# Enter the mathematical expression 2+2/2
# Your result is 3.0
# Thank you

# %% [markdown]
# Suppose you are analyzing a dataset containing information about house prices in a city. Each record includes details such as the house size (in sq feet), number of bedrooms, and price. You want to perform various calculations and manipulations on this dataset using Python.
#
# Answer the following question:
#
# 1) Ask the user 1 & 2 to enter ther house size, number of rooms they want and check the datatype user has entered.
# 2) calculate the price of the house , if per sq feet is Rs. 5000.
# 3) Threshold price is 75 lakh Rs. which  user is paying the price above threshold price.

# %%
user1_h1 = float(input("User 1 Enter the house size"))
user1_room = int(input("User 1 Enter the  no. of rooms"))
user1_price = float(input("User 1 Enter your budget"))

user2_h2 = float(input("User 2 Enter the house size"))
user2_room = int(input("User 2 Enter the  no. of rooms"))
user2_price = float(input("User 2 Enter your budget"))

house_price_1 = user1_h1 * 5000
print ("Price of user1 house is",house_price_1)

house_price_2 = user2_h2 * 5000
print ("Price of user2 house is",house_price_2)

threshold_price = 7500000
user1_threshold = house_price_1 >= threshold_price
user2_threshold = house_price_2 >= threshold_price

print(f"User 1 paid above the threshold price",user1_threshold)
print(f"User 2 paid above the threshold price",user2_threshold)
# Out:
# User 1 Enter the house size 1000
# User 1 Enter the  no. of rooms 2
# User 1 Enter your budget 6000000
# User 2 Enter the house size 1500
# User 2 Enter the  no. of rooms 4
# User 2 Enter your budget 8000000
# Price of user1 house is 5000000.0
# Price of user2 house is 7500000.0
# User 1 paid above the threshold price False
# User 2 paid above the threshold price True

# %% [markdown]
# You are working on a project to analyze stock market data.
# Create variables to store the stock symbol, current price, and percentage change in price. Then calculate the new price after a 10% increase using arithematic operators. Finally , prompt the user to enter their budget  using the  input() function, compare it with the new price.

# %%
stock_symbol = "abc"
current_price = 100

percentage_change = 10 
new_price = current_price * (1 + percentage_change/100)

print("new price is", new_price)

user_budget = int(input("Enter your budget"))

compare_budget = user_budget >= new_price
print("User budget is greater than new price.", compare_budget)
# Out:
# new price is 110.00000000000001
# Enter your budget 111
# User budget is greater than new price. True

# %% [markdown]
# You are working on a project to analyze weather data. Create variables to store the current temperature,the minimum temperature recorded, and the maximum temperature recorded. determine whether the current temperature is within the range of the minimum and maximum temperatures recorded using logical operators.

# %%
current_temp = float(input("Enter the current temperature"))
min_temp = 20
max_temp = 35

if min_temp <= current_temp <= max_temp:
    print("The current temperature is", current_temp, "is within the range of", min_temp, "and", max_temp)
else:
    print(f"The current temperature is {current_temp} is out of range {min_temp} and {max_temp}")
# Out:
# Enter the current temperature 36
# The current temperature is 36.0 is out of range 20 and 35
