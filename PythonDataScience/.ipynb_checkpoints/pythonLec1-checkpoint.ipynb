# %% [raw]
# Variables and data Types inn Python

# %% [raw]
# Creating a variable

# %%
a = 4
print(a)
# Out:
# 4

# %%
a =   19
b=2
c='anuj'
print(a+b)
print(a,b,c)
# Out:
# 21
# 19 2 anuj

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# a                      int         19
# b                      int         2
# c                      str         anuj
# dataframe_columns      function    <function dataframe_columns at 0x10382c220>
# dataframe_hash         function    <function dataframe_hash at 0x12f1be7a0>
# dtypes_str             function    <function dtypes_str at 0x12f1bf740>
# get_dataframes         function    <function get_dataframes at 0x12f2fd4e0>
# getpass                module      <module 'getpass' from '/<...>b/python3.11/getpass.py'>
# hashlib                module      <module 'hashlib' from '/<...>b/python3.11/hashlib.py'>
# import_pandas_safely   function    <function import_pandas_safely at 0x12f2fd800>
# is_data_frame          function    <function is_data_frame at 0x1035b4400>
# json                   module      <module 'json' from '/opt<...>on3.11/json/__init__.py'>

# %% [raw]
# #Rules
# -A variable name must start with a letter or the underscore character
# -A variable name cannot start with a number.
# -A variable name can only contain alpha-numeric characters and underscores(A-Z, 0-9,  and _)
# -Variable names are case sensitive(Apple, apple, and APPLE are three different        variables)
# -A variable name cannot be any of the Python keywords.

# %%
anjal = 2.5
print(anjal)


_abc = "anjalansh"
print(_abc)
# Out:
# 2.5
# anjalansh

# %%
@2= 34
print(@2)
# Out:
#   Cell In[18], line 1
#     @2= 34
#      ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [raw]
# Data Types, int, float, String, Complex, list , boolean

# %%
a= 3
b="anuj"
c=4.4
print(a, b,  c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 3 anuj 4.4
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [raw]
# Data Types are {List[], Tuple(), Set{} and Dictionary{}}

# %%
myNum = [1,2,3,4]
print(myNum)
print(type(myNum))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
alive=True
print(alive)
print(type(alive))
# Out:
# True
# <class 'bool'>

# %%
dead = False
print(dead)
print(type(dead))
# Out:
# False
# <class 'bool'>

# %% [raw]
# Reserved keyword annot be used as variable

# %% [raw]
# Imagine you're working on a customer management system and you have the firstname
# and lastname of a customer stored as seperate variables.
# You're developing a customer management system for a retail store. In your database,
# you have the first name and lastname of a customer stored as seperate variables: first_name="John"
# and lastName="Doe".
# How would you concatenate these strings to form the full name
# "John Doe" for the customer's profile.

# %%
first_name = "John"
last_name = "Doe"
full_name = first_name + " " + last_name

print (full_name)
# Out:
# John Doe

# %% [raw]
# you have a variable x with the value of 5. How would you reassign x to have the value 10?

# %%
x = 5
print(x)

#Reassign th
x = 10
print(x)
# Out:
# 5
# 10
