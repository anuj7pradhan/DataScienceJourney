# %% [raw]
# Lec 4
# Built in function

# %% [raw]
# Float function

# %%
num = 2
print(type(num))

#changing int to float

a = float(num)
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a = "3.14"
print(type(a))
b = float(a)
print("the no. b is:",b)
print(type(b))
# Out:
# <class 'str'>
# the no. b is: 3.14
# <class 'float'>

# %% [raw]
# int function

# %%
a = 342.2
print(type(a))
b =  int(a)
         
print("This is  b",b)
# Out:
# <class 'float'>
# THis is  b 342

# %%
a1 = "43"
print("This is a1",type(a1))
b1 = int(a1)
print("This is b1",type(b1))
# Out:
# This is a1 <class 'str'>
# This is b1 <class 'int'>

# %% [raw]
# str functiion

# %%
a = 32
print(type(a))
b = str(a)
print("This is b: ",  type(b))
c = "4"
print(b+c)
# Out:
# <class 'int'>
# This is b:  <class 'str'>
# 324

# %% [raw]
# Complex function

# %%
comp = complex(2,3)
print(comp)
# Out:
# (2+3j)

# %%
a =4
b=3
c=complex(a,b)
print(c)
# Out:
# (4+3j)

# %% [raw]
# abs function

# %%
# returns to absolute  value
x = -25
print(abs(x))
# Out:
# 25

# %%
a =  -45.454 #Float value also can be changed to absolute value
print(abs(a))
# Out:
# 45.454

# %% [raw]
# len function #used to count the  no. of list

# %%
a = "I am Anuj and I am glad to be your friend"
print(len(a))
# Out:
# 41

# %%
b="bb bb" # space is also calulated by len function
print(len(b))
# Out:
# 5

# %%
c =[1,2,3,9,4,5,4,9,2,45,6,7,8,7,8,9]
print(len(c))
# Out:
# 16

# %% [raw]
# In  a game application, the player's score is stored as a floating-point number.
# However, for leaderboard display, you  need to convert the score to an integer.
# How would you use the int() function  to convert the player's score from floation-point to integer format?
# Pls solvethis with  code, player score = 1234.56

# %%
player_score = 1234.56
print("The player score is: ",int(player_score))
# Out:
# The player score is:  1234

# %% [raw]
# In a customer relationship management(CRM) system for a retail company, you have a database containing customer records. How would you use the len() function to find the total number of customers in the  database, allowing the company to track its customer base?
#
# customer_database = [
# (1, 'John Doe', 'john@example.com'),
# (2, 'Jane Smith', 'jane@example.com'),
# (3, 'Alice Johnson','alice@example.com'),
# ]

# %%
customer_database = [
(1, 'John Doe', 'john@example.com'),
(2, 'Jane Smith', 'jane@example.com'),
(3, 'Alice Johnson','alice@example.com'),
]
print("The total no. of customers in a database is: ",len(customer_database))
# Out:
# The total no. of customers in a database is:  3

# %% [raw]
# You're developing a financial application that calculates simple  interest. The principal amount is 250000, the  interest rate is 9.34567%, and the time period is 3 years. Calculate the simple interest(SI), and the  final value should be an integer.

# %%
p = 250000
r = 9.34567
t = 3

si= p * t * r/100
print("The si is: ",si)
print("The final si value is", int(si) )
# Out:
# The si is:  70092.525
# The final si value is 70092

# %% [raw]
# You're working at a travel company, responsible for managing passenger information. Due to a technical glitch in the booking system, some passenger's ages were mistakenly recorded as negative values. However, age cannot be negative, and it's essential to correct this data inconsistency before furtheranalysis or reporting. Which function you  will use to correct the ages of all passengers in the  dataset where negative ages were recorded due to the technical glitch.

# %%
#age = [-24, -33, -54]

#print(abs(age))

a=-35
print(abs(a))
# Out:
# 35
