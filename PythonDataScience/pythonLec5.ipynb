# %% [raw]
# Lec 5
# Built in function(part 2)
# Bin Function

# %% [raw]
# # the bin function is used  to convert the integer number to its binary representation as a string prefixed with '0b'.
# #It takes an integer as an argument and returnsits binary representation.

# %%
binary_rep = bin(10)
print("Binary  of 10 is: ",binary_rep)
# Out:
# Binary  of 10 is:  0b1010

# %% [raw]
# sum Function

# %%
a = [1,2,3,4,5,6,7,8,9,8,7,6,7,8,53,34,5,7,]
print(sum(a))
# Out:
# 180

# %%
a = [1,2,3,4,5,6,7,8,9,8,7,6,7,8,53,34,5,7,]
b=sum(a)
print(b)
# Out:
# 180

# %%
a = [1,2,3,4,5,6]
starting_value = 10
print(sum(a,starting_value))
# Out:
# 31

# %% [raw]
# Eval Function

# %% [raw]
# eval() function evaluates a python expression stored in a string

# %%
x = 10
y = 21
expression = "x + y *2"
print (eval(expression))
# Out:
# 52

# %%
exp = "5/2+3.5"
print(eval(exp))
print(type(exp))
# Out:
# 6.0
# <class 'str'>

# %%
exp1 = "2+2*3/6*4%3"
print(eval(exp1))
print(type(exp1))
# Out:
# 3.0
# <class 'str'>

# %%
x=3
y=5
z=12
exp = "x+y*z+x-z"
print(eval(exp))
# Out:
# 54

# %% [raw]
# Help Function

# %% [raw]
# Help functioin is used to document the modules, functions, classes, keywords , etc

# %%
help()
# Out:
# Welcome to Python 3.11's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.11/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
# help>  stiring
# No Python documentation found for 'stiring'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
# help>  string
# Help on module string:
#
# NAME
#     string - A collection of string constants.
#
# MODULE REFERENCE
# ...

# %% [markdown]
# INPUT FUNCTION

# %%
name = input("Enter your name.")
print("Your name is", name)
# Out:
# Enter your name. anjal
# Your name is anjal

# %% [markdown]
# input function is a string type data

# %%
age = input("Enter your age")
print("your age is",age)
print(type(age))
# Out:
# Enter your age 33
# your age is 33
# <class 'str'>

# %%
PRACTICE QUESTIONS

# %%
Q1

# %%
Get two numbers from the user and calculate their sum.

# %%
first_num = int(input("Enter first number."))
second_num = int(input("Enter second number."))

sum = first_num + second_num
print("Your sum is", sum)
# Out:
# Enter first number. 12
# Enter second number. 2
# Your sum is 14

# %%
Q2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Q2
#
# NameError: name 'Q2' is not defined

# %% [markdown]
# As a part of yur role in a data-driven project,
# you need to take input  from the user for theor age, weight, and height.
# however , there's an issue: the user has entered their age as a negative number.
# you need to corect the age of the user , and after correcting the  age. calculate their Basal Metabolic Rate (BMR) using the  Harris-Benidict equation for men. Ensure that the final answer of BMR is an integer.
#
# Basal Metabolic Rate (BMR):
# Formula (Harris-Benidict equation for men):
# BMR = 88.362 +  (13.397 * weight in kg) + (4.799 * height in cm) - (5.677 * age in years)

# %%
age = int(input("Enter your age"))
weight =int(input("Enter your weight"))
height =float(input("Enter your height"))

print("You are",  abs(age), "years old,", "You weight", weight, "kg and", "Your height is", height, "cm.")

BMR = "88.362 +  (13.397 * weight) + (4.799 * height) - (5.677 * age)"
bmr = eval(BMR)
print("Your BMR is",int(bmr))
# Out:
# Enter your age -45
# Enter your weight 56
# Enter your height 8.3
# You are 45 years old, You weight 56 kg and Your height is 8.3 cm.
# Your BMR is 1133

# %%
HomeWork

# %% [markdown]
# Write a python program for a hostel students, ask them to mention their course name and age. for 5 students and calculate their avg age

# %%
std1_course = input("Enter your course name")
std1_age = int(input("Enter your age."))

std2_course = input("Enter your course name")
std2_age = int(input("Enter your age."))

std3_course = input("Enter your course name")
std3_age = int(input("Enter your age."))

std4_course = input("Enter your course name")
std4_age = int(input("Enter your age."))

std5_course = input("Enter your course name")
std5_age = int(input("Enter your age."))

avg_age = (std1_age + std2_age + std3_age + std4_age + std5_age) / 5

print("The average age of the students is",avg_age)
# Out:
# Enter your course name
# Enter your age. 1
# Enter your course name
# Enter your age. 2
# Enter your course name
# Enter your age. 3
# Enter your course name
# Enter your age. 4
# Enter your course name
# Enter your age. 5
# The average age of the students is 3.0
