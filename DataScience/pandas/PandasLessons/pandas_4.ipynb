# %%
import pandas as pd

# %%
# df = pd.read_csv('Desktop/pandas/results.csv', index_col = 'MainBranch')
df = pd.read_csv('Desktop/pandas/results.csv', index_col = 'ResponseId')
schema_df = pd.read_csv('Desktop/pandas/schema.csv', index_col = 'qname')
# Out:
# /var/folders/pq/zbs3jsgn6054khs3f3z3k7r40000gp/T/ipykernel_1063/1863193220.py:2: DtypeWarning: Columns (0: AIThreat, 1: DatabaseWantEntry, 2: DevEnvWantEntry, 3: SOTagsWant Entry, 4: OpSysPersonal use, 5: CommPlatformHaveWorkedWith, 6: CommPlatformWantEntr, 7: AIModelsChoice, 8: SOComm, 9: AIAgentOrchWrite, 10: AIAgentExternal) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Desktop/pandas/results.csv', index_col = 'ResponseId')

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
pd.set_option('display.max_columns',70)
pd.set_option('display.max_rows',70)

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
high_salary_yearly = (df['ConvertedCompYearly'] > 700000)

# %%
df.loc[high_salary_yearly]
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 552         I am a developer by profession  55-64 years old
# 727         I am a developer by profession  25-34 years old
# 1108        I am a developer by profession  25-34 years old
# 1126        I am a developer by profession  35-44 years old
# 1610        I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 48024       I am a developer by profession  18-24 years old
# 48178       I am a developer by profession  18-24 years old
# 48429          I code primarily as a hobby  18-24 years old
# 48840       I am a developer by profession  45-54 years old
# 48935       I am a developer by profession  35-44 years old
#
#                                                       EdLevel  \
# ResponseId
# 552              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 727         Some college/university study without earning ...
# ...

# %%
df.loc[high_salary_yearly, ['LearnCode', 'DevType','ConvertedCompYearly']] # Just checking the informations from the column LearnCode, DevType, and ConvertedCompYearly
# Out:
#                                                     LearnCode  \
# ResponseId
# 552         Books / Physical media;Colleague or on-the-job...
# 727         Other online resources (e.g. standard search, ...
# 1108        Online Courses or Certification (includes all ...
# 1126        Online Courses or Certification (includes all ...
# 1610        Other online resources (e.g. standard search, ...
# ...                                                       ...
# 48024       Online Courses or Certification (includes all ...
# 48178       Online Courses or Certification (includes all ...
# 48429       Other online resources (e.g. standard search, ...
# 48840                                                     NaN
# 48935                                                     NaN
#
#                                                   DevType  ConvertedCompYearly
# ResponseId
# 552         Developer, desktop or enterprise applications             800000.0
# ...

# %%
DevType =  ['Developer, full-stack', 'Student', 'Engineering manager','eveloper, back-end']
filt = df['DevType'].isin(DevType)

# %%
df.loc[filt,'DevType']
# Out:
# ResponseId
# 5          Engineering manager
# 7        Developer, full-stack
# 14       Developer, full-stack
# 18       Developer, full-stack
# 23       Developer, full-stack
#                  ...
# 49158    Developer, full-stack
# 49169    Developer, full-stack
# 49173    Developer, full-stack
# 49177    Developer, full-stack
# 49191                  Student
# Name: DevType, Length: 16427, dtype: str

# %%
df['DevType']
# Out:
# ResponseId
# 1                       Developer, mobile
# 2                     Developer, back-end
# 3                    Developer, front-end
# 4                     Developer, back-end
# 5                     Engineering manager
#                        ...
# 49187                                 NaN
# 49188                                 NaN
# 49189    Architect, software or solutions
# 49190                                 NaN
# 49191                             Student
# Name: DevType, Length: 49191, dtype: str

# %%
filt = df['DevType'].str.contains('Developer', na = False)

# %%
print(filt)
# Out:
# ResponseId
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
#          ...
# 49187    False
# 49188    False
# 49189    False
# 49190    False
# 49191    False
# Name: DevType, Length: 49191, dtype: bool

# %%
df.loc[filt, 'DevType']
# Out:
# ResponseId
# 1                                    Developer, mobile
# 2                                  Developer, back-end
# 3                                 Developer, front-end
# 4                                  Developer, back-end
# 6                                  Developer, back-end
#                              ...
# 49169                            Developer, full-stack
# 49173                            Developer, full-stack
# 49177                            Developer, full-stack
# 49180                                Developer, mobile
# 49181    Developer, desktop or enterprise applications
# Name: DevType, Length: 26392, dtype: str
