# %%
import pandas as pd

# %%
df = pd.read_csv('Desktop/pandas/results.csv')

# schema_df = pd.read_csv('Desktop/pandas/schema.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('Desktop/pandas/results.csv')
#       2
#       3 # schema_df = pd.read_csv('Desktop/pandas/schema.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
schema_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 schema_df
#
# NameError: name 'schema_df' is not defined

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.columns

# %%
df['WorkExp']

# %%
df['WorkExp'].value_counts()

# %%
df.MainBranch

# %%
df['MainBranch'].value_counts()

# %%
df.JobSat

# %%
df['JobSat'].value_counts()

# %%
df.LearnCodeAI

# %%
df.LearnCodeAI.value_counts()

# %%
df["EdLevel"]

# %%
df['EdLevel'].value_counts()

# %%
df['WorkExp']

# %%
df.loc[0] # this is a one person's entire responses

# %%
df.loc[0,"WorkExp"] # Finding the work experience of the first person's response

# %%
df.loc[0:2,"MainBranch":"LearnCode"] # Slicing from 0 to 2nd row and from MainBranch to LeanrnCode column

# %%
# person = {
#     "firstName": "Suncha",
#     "lastName": "voxx",
#     "email": "Sunchavoxx@gmail.com"
# }

# %%
# # it's a list of people that can be extended as reuirement
# people = {
#     "firstName": ["Suncha"],
#     "lastName": ["voxx"],
#     "email": ["Sunchavoxx@gmail.com"]
# }

# %%
# # it's a list of people that can be extended as reuirement
# people = {
#     "firstName": ["Suncha", "sirish","sabin", "mika"],
#     "lastName": ["voxx", "dalli", "rai", "dalli"],
#     "email": ["Sunchavoxx@gmail.com", "sirishdalli@gmail.com","sabinrai@gmail.com", "mikadalli@gmail.com"]
# }

# %%
# people['email']

# %%
# import pandas as pd

# %%
# df = pd.DataFrame(people) # making a dataframe of the people

# %%
# df # printinng all the data frame available in the people list

# %%
# df['email'] # displaying email dataframe using [brackets]

# %%
# type(df['email'])

# %%
# df.email # using dot for displaying

# %%
# df.count

# %%
# df[['lastName', 'email']]

# %%
# df.columns # looking for the column name

# %%
# # Getting row values
# # 1. loc
# # 2. iloc
# df.iloc[0] # returns the series of the first row of the people

# %%
# df.iloc[2]

# %%
# df.iloc[[0,2,1]]

# %%
# df.iloc[[0,1],2]

# %%
# df # Entire data frame

# %%
# df.loc[0]

# %%
# df.loc[[0,1]]

# %%
# df.loc[[0,1],'email'] # email of index 0 and 1

# %%
# df.loc[[0,1,2],['email','lastName']] # email and lastName of index 0, 1 and 2
