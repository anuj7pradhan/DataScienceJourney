# %%
import pandas as pd

# %%
df = pd.read_csv('Desktop/pandas/results.csv')
# Out:
# /var/folders/pq/zbs3jsgn6054khs3f3z3k7r40000gp/T/ipykernel_9796/1268165210.py:1: DtypeWarning: Columns (0: JobSatPoints_15_TEXT, 1: DatabaseHaveEntry, 2: DevEnvHaveEntry, 3: SOTagsHaveEntry, 4: SOTagsWant Entry, 5: OfficeStackWantEntry, 6: CommPlatformHaveEntr, 7: CommPlatformWantEntr, 8: SO_Actions_15_TEXT, 9: AIAgentOrchestration, 10: AIAgentObsWrite) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Desktop/pandas/results.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df.loc[1]
# Out:
# ResponseId                                                             2
# MainBranch                                I am a developer by profession
# Age                                                      25-34 years old
# EdLevel                              Associate degree (A.A., A.S., etc.)
# Employment                                                      Employed
#                                              ...
# AIAgentExtWrite                                                      NaN
# AIHuman                When I don’t trust AI’s answers;When I want to...
# AIOpen                                         All skills. AI is a flop.
# ConvertedCompYearly                                             104413.0
# JobSat                                                               9.0
# Name: 1, Length: 172, dtype: object

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=172)

# %%
df['JobSat']
# Out:
# 0        10.0
# 1         9.0
# 2         8.0
# 3         6.0
# 4         7.0
#          ...
# 49186     NaN
# 49187     NaN
# 49188     9.0
# 49189     NaN
# 49190     NaN
# Name: JobSat, Length: 49191, dtype: float64

# %%
df['EmploymentAddl']
# Out:
# 0        Caring for dependents (children, elderly, etc.)
# 1                                                    NaN
# 2                                      None of the above
# 3                                      None of the above
# 4        Caring for dependents (children, elderly, etc.)
#                               ...
# 49186                                                NaN
# 49187    Caring for dependents (children, elderly, etc.)
# 49188                                  None of the above
# 49189                                  None of the above
# 49190                       Attending school (full-time)
# Name: EmploymentAddl, Length: 49191, dtype: str

# %%
df['Age']
# Out:
# 0        25-34 years old
# 1        25-34 years old
# 2        35-44 years old
# 3        35-44 years old
# 4        35-44 years old
#               ...
# 49186    18-24 years old
# 49187    45-54 years old
# 49188    35-44 years old
# 49189    25-34 years old
# 49190    18-24 years old
# Name: Age, Length: 49191, dtype: str

# %%
df.set_index('Age',inplace = True) # set the index as Age columns

# %%
df.index # just querying what is the recent index of the file
# Out:
# Index(['25-34 years old', '25-34 years old', '35-44 years old',
#        '35-44 years old', '35-44 years old', '45-54 years old',
#        '25-34 years old', '35-44 years old', '25-34 years old',
#        '25-34 years old',
#        ...
#        '25-34 years old', '35-44 years old', '25-34 years old',
#        '45-54 years old', '25-34 years old', '18-24 years old',
#        '45-54 years old', '35-44 years old', '25-34 years old',
#        '18-24 years old'],
#       dtype='str', name='Age', length=49191)

# %%
df.loc['25-34 years old'] # location of 25-34 years old
# Out:
#                  ResponseId                      MainBranch  \
# Age
# 25-34 years old           1  I am a developer by profession
# 25-34 years old           2  I am a developer by profession
# 25-34 years old           7  I am a developer by profession
# 25-34 years old           9  I am a developer by profession
# 25-34 years old          10  I am a developer by profession
# ...                     ...                             ...
# 25-34 years old       49180  I am a developer by profession
# 25-34 years old       49182  I am a developer by profession
# 25-34 years old       49184  I am a developer by profession
# 25-34 years old       49186  I am a developer by profession
# 25-34 years old       49190  I am a developer by profession
#
#                                                            EdLevel  \
# Age
# 25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 25-34 years old                Associate degree (A.A., A.S., etc.)
# ...

# %%
df.loc['35-44 years old'] # extract all the information of the location 35-44 years old
# Out:
#                  ResponseId                      MainBranch  \
# Age
# 35-44 years old           3  I am a developer by profession
# 35-44 years old           4  I am a developer by profession
# 35-44 years old           5  I am a developer by profession
# 35-44 years old           8  I am a developer by profession
# 35-44 years old          13  I am a developer by profession
# ...                     ...                             ...
# 35-44 years old       49149  I am a developer by profession
# 35-44 years old       49163  I am a developer by profession
# 35-44 years old       49178           I am learning to code
# 35-44 years old       49183  I am a developer by profession
# 35-44 years old       49189  I am a developer by profession
#
#                                                          EdLevel  \
# Age
# 35-44 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35-44 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df['EmploymentAddl'] # extracts the Age as the index and all the related EmploymentAddl
# Out:
# Age
# 25-34 years old    Caring for dependents (children, elderly, etc.)
# 25-34 years old                                                NaN
# 35-44 years old                                  None of the above
# 35-44 years old                                  None of the above
# 35-44 years old    Caring for dependents (children, elderly, etc.)
#                                         ...
# 18-24 years old                                                NaN
# 45-54 years old    Caring for dependents (children, elderly, etc.)
# 35-44 years old                                  None of the above
# 25-34 years old                                  None of the above
# 18-24 years old                       Attending school (full-time)
# Name: EmploymentAddl, Length: 49191, dtype: str

# %%
df.loc['EmploymentAddl'] # EmploymentAddl is not the index of the file
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:192, in pandas._libs.index.IndexEngine.get_loc()
# --> 192 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:235, in pandas._libs.index.IndexEngine._get_loc_duplicates()
# --> 235 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.reset_index(inplace=True) # reset_index resets the Age index to the default column

# %%
df
# Out:
#                    Age  ResponseId  \
# 0      25-34 years old           1
# 1      25-34 years old           2
# 2      35-44 years old           3
# 3      35-44 years old           4
# 4      35-44 years old           5
# ...                ...         ...
# 49186  18-24 years old       49187
# 49187  45-54 years old       49188
# 49188  35-44 years old       49189
# 49189  25-34 years old       49190
# 49190  18-24 years old       49191
#
#                                               MainBranch  \
# 0                         I am a developer by profession
# 1                         I am a developer by profession
# 2                         I am a developer by profession
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# ...                                                  ...
# 49186                        I code primarily as a hobby
# 49187                     I am a developer by profession
# ...

# %%
df.iloc[0]
# Out:
# Age                                                    25-34 years old
# ResponseId                                                           1
# MainBranch                              I am a developer by profession
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 0, Length: 172, dtype: object

# %%
df = pd.read_csv('Desktop/pandas/results.csv')
# Out:
# /var/folders/pq/zbs3jsgn6054khs3f3z3k7r40000gp/T/ipykernel_9796/1268165210.py:1: DtypeWarning: Columns (0: JobSatPoints_15_TEXT, 1: DatabaseHaveEntry, 2: DevEnvHaveEntry, 3: SOTagsHaveEntry, 4: SOTagsWant Entry, 5: OfficeStackWantEntry, 6: CommPlatformHaveEntr, 7: CommPlatformWantEntr, 8: SO_Actions_15_TEXT, 9: AIAgentOrchestration, 10: AIAgentObsWrite) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Desktop/pandas/results.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df = pd.read_csv('Desktop/pandas/results.csv', index_col = "ResponseId") # ResponseId is a new index
# Out:
# /var/folders/pq/zbs3jsgn6054khs3f3z3k7r40000gp/T/ipykernel_9796/1912988701.py:1: DtypeWarning: Columns (0: AIThreat, 1: DatabaseWantEntry, 2: DevEnvWantEntry, 3: SOTagsWant Entry, 4: OpSysPersonal use, 5: CommPlatformHaveWorkedWith, 6: CommPlatformWantEntr, 7: AIModelsChoice, 8: SOComm, 9: AIAgentOrchWrite, 10: AIAgentExternal) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Desktop/pandas/results.csv', index_col = "ResponseId")

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df.loc[1] # this is the response from the ResponseId.
# Out:
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
# EmploymentAddl         Caring for dependents (children, elderly, etc.)
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 1, Length: 171, dtype: object

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
df = pd.read_csv('Desktop/pandas/schema.csv')

# %%
df
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %%
df.set_index('qname',inplace = True)

# %%
df
# Out:
#                     qid                                           question  \
# qname
# TechEndorse_1     QID18  What attracts you to a technology or causes yo...
# TechEndorse_2     QID18  What attracts you to a technology or causes yo...
# TechEndorse_3     QID18  What attracts you to a technology or causes yo...
# TechEndorse_4     QID18  What attracts you to a technology or causes yo...
# TechEndorse_5     QID18  What attracts you to a technology or causes yo...
# ...                 ...                                                ...
# AIAgentObsWrite  QID103  Was the tool or tools for AI agent observabili...
# AIAgentExternal   QID92  You indicated you use or develop AI agents as ...
# AIAgentExtWrite  QID104  Was the out-of-the-box agents, copilots or ass...
# AIHuman          QID100  In the future, if AI can do most coding tasks,...
# AIOpen            QID93  Looking ahead 3–5 years, what skills do you be...
#
# ...

# %%
df.loc['TechEndorse_1'] # here the location of the TechEndorse_1
# Out:
# qid                                                     QID18
# question    What attracts you to a technology or causes yo...
# type                                                       RO
# sub                   AI integration or AI Agent capabilities
# sq_id                                                     1.0
# Name: TechEndorse_1, dtype: object

# %%
df.loc['TechEndorse_1', 'question'] ## here the location of the TechEndorse_1 and it's question
# Out:
# 'What attracts you to a technology or causes you to endorse it (most to least important)?'

# %%
df.loc['TechEndorse_1','question':'sub'] # here the location of the TechEndorse_1 and it's question to sub column
# Out:
# question    What attracts you to a technology or causes yo...
# type                                                       RO
# sub                   AI integration or AI Agent capabilities
# Name: TechEndorse_1, dtype: object

# %%
df.sort_index() # sorts the table in ascending order of the index qname
# Out:
#                       qid                                           question  \
# qname
# AIAcc               QID80  How much do you trust the accuracy of the outp...
# AIAgentChallenges   QID88  To what extent do you agree with the following...
# AIAgentChange       QID83  Have AI tools or AI agents changed how you com...
# AIAgentExtWrite    QID104  Was the out-of-the-box agents, copilots or ass...
# AIAgentExternal     QID92  You indicated you use or develop AI agents as ...
# ...                   ...                                                ...
# WebframeChoice      QID47  Did you work with web frameworks and web techn...
# WebframeHaveEntry   QID58  Were the web frameworks and web technologies y...
# WebframeWantEntry   QID59  Were the web frameworks and web technologies y...
# WorkExp             QID14  How many years of professional work experience...
# YearsCode           QID13  Including any education, how many years have y...
#
# ...

# %%
df.sort_index(ascending = False) # sorts the table in decending order of the index qname
# Out:
#                       qid                                           question  \
# qname
# YearsCode           QID13  Including any education, how many years have y...
# WorkExp             QID14  How many years of professional work experience...
# WebframeWantEntry   QID59  Were the web frameworks and web technologies y...
# WebframeHaveEntry   QID58  Were the web frameworks and web technologies y...
# WebframeChoice      QID47  Did you work with web frameworks and web techn...
# ...                   ...                                                ...
# AIAgentExternal     QID92  You indicated you use or develop AI agents as ...
# AIAgentExtWrite    QID104  Was the out-of-the-box agents, copilots or ass...
# AIAgentChange       QID83  Have AI tools or AI agents changed how you com...
# AIAgentChallenges   QID88  To what extent do you agree with the following...
# AIAcc               QID80  How much do you trust the accuracy of the outp...
#
# ...
