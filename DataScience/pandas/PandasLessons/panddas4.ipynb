# %%
# Let's learn about the Filtering - Using Conditionals to Filter Rows and Columns
people = {
    "firstName": ["Suncha", "sirish","sabin", "mika"],
    "lastName": ["voxx", "dalli", "rai", "dalli"],
    "email": ["Sunchavoxx@gmail.com", "sirishdalli@gmail.com","sabinrai@gmail.com", "mikadalli@gmail.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#   firstName lastName                  email
# 0    Suncha     voxx   Sunchavoxx@gmail.com
# 1    sirish    dalli  sirishdalli@gmail.com
# 2     sabin      rai     sabinrai@gmail.com
# 3      mika    dalli    mikadalli@gmail.com

# %%
# filt = (df['lastName'] == 'dalli') # filter to execute list that equals to dalli

# %%
# print(filt)

# %%
# df[filt]

# %%
# df.loc[filt]

# %%
# df.loc[filt,'email']

# %%
filt = (df['lastName']=='dalli') & (df['firstName'] == 'sirish')

# %%
df.loc[filt, 'email'] #just filtering the email attribute from filt
# Out:
# 1    sirishdalli@gmail.com
# Name: email, dtype: str

# %%
df.loc[-filt,'email'] # -filt means a negation filt
# Out:
# 0    Sunchavoxx@gmail.com
# 2      sabinrai@gmail.com
# 3     mikadalli@gmail.com
# Name: email, dtype: str
