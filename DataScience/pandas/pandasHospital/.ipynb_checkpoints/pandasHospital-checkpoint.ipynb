# %%
import pandas as pd

# %%
df = pd.read_csv('hospitalDataAnalysis.csv')

# %%
df
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
df.head()   # head function provides first 5 rows
# Out:
#    Patient_ID  Age  Gender      Condition                 Procedure   Cost  \
# 0           1   45  Female  Heart Disease               Angioplasty  15000
# 1           2   60    Male       Diabetes           Insulin Therapy   2000
# 2           3   32  Female  Fractured Arm          X-Ray and Splint    500
# 3           4   75    Male         Stroke    CT Scan and Medication  10000
# 4           5   50  Female         Cancer  Surgery and Chemotherapy  25000
#
#    Length_of_Stay Readmission    Outcome  Satisfaction
# 0               5          No  Recovered             4
# 1               3         Yes     Stable             3
# 2               1          No  Recovered             5
# 3               7         Yes     Stable             2
# 4              10          No  Recovered             4

# %%
df.tail()   # tail function provides last 5 rows
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# 979   1000              70          No     Stable             4
# 980   8000              72          No  Recovered             3
# 981   3000              72          No  Recovered             4
# 982  18000              74         Yes     Stable             2
# 983    100              68          No  Recovered             5

# %%
df.head(3)  # head function with parameter provides first rows
# Out:
#    Patient_ID  Age  Gender      Condition         Procedure   Cost  \
# 0           1   45  Female  Heart Disease       Angioplasty  15000
# 1           2   60    Male       Diabetes   Insulin Therapy   2000
# 2           3   32  Female  Fractured Arm  X-Ray and Splint    500
#
#    Length_of_Stay Readmission    Outcome  Satisfaction
# 0               5          No  Recovered             4
# 1               3         Yes     Stable             3
# 2               1          No  Recovered             5

# %%
df.tail(3)  # tail function with parameter provides last rows
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# 981   3000              72          No  Recovered             4
# 982  18000              74         Yes     Stable             2
# 983    100              68          No  Recovered             5

# %%
df.info()   # All the information of the dataframe is provided
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 10 columns):
# datatype is also shown
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      984 non-null    int64
#  1   Age             984 non-null    int64
#  2   Gender          984 non-null    str
#  3   Condition       984 non-null    str
#  4   Procedure       984 non-null    str
#  5   Cost            984 non-null    int64
#  6   Length_of_Stay  984 non-null    int64
#  7   Readmission     984 non-null    str
#  8   Outcome         984 non-null    str
#  9   Satisfaction    984 non-null    int64
# dtypes: int64(5), str(5)
# memory usage: 77.0 KB

# %%
df.describe()   # Statistical informations, mean, count, std etc...
# Out:
#         Patient_ID         Age          Cost  Length_of_Stay  Satisfaction
# count   984.000000  984.000000    984.000000      984.000000    984.000000
# mean    500.329268   53.754065   8367.479675       37.663618      3.598577
# std     288.979531   14.941135   7761.990976       19.595805      0.883002
# min       1.000000   25.000000    100.000000        1.000000      2.000000
# 25%     250.750000   45.000000   1000.000000       21.000000      3.000000
# 50%     500.500000   55.000000   6000.000000       38.000000      4.000000
# 75%     750.250000   65.000000  15000.000000       54.250000      4.000000
# max    1000.000000   78.000000  25000.000000       76.000000      5.000000

# %%
df.index    # idexes that started from is shown i.e RangeIndex(start=0, stop=984, step=1)
# Out:
# RangeIndex(start=0, stop=984, step=1)

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Condition', 'Procedure', 'Cost',
#        'Length_of_Stay', 'Readmission', 'Outcome', 'Satisfaction'],
#       dtype='str')

# %%
df['Condition'] # values that are present inside of Condition column
# Out:
# 0          Heart Disease
# 1               Diabetes
# 2          Fractured Arm
# 3                 Stroke
# 4                 Cancer
#              ...
# 979         Hypertension
# 980         Appendicitis
# 981        Fractured Leg
# 982         Heart Attack
# 983    Allergic Reaction
# Name: Condition, Length: 984, dtype: str

# %%
df[['Condition','Procedure']]   # values that are present inside of Condition Column and Procedure Column
# Out:
#              Condition                  Procedure
# 0        Heart Disease                Angioplasty
# 1             Diabetes            Insulin Therapy
# 2        Fractured Arm           X-Ray and Splint
# 3               Stroke     CT Scan and Medication
# 4               Cancer   Surgery and Chemotherapy
# ..                 ...                        ...
# 979       Hypertension  Medication and Counseling
# 980       Appendicitis               Appendectomy
# 981      Fractured Leg  Cast and Physical Therapy
# 982       Heart Attack    Cardiac Catheterization
# 983  Allergic Reaction      Epinephrine Injection
#
# [984 rows x 2 columns]

# %%
len(df["Condition"] )   # shows how many values are located in the COndition column
# Out:
# 984

# %%
df.iloc[0] # iloc - Index Location of 0th row full information is. provided
# Out:
# Patient_ID                    1
# Age                          45
# Gender                   Female
# Condition         Heart Disease
# Procedure           Angioplasty
# Cost                      15000
# Length_of_Stay                5
# Readmission                  No
# Outcome               Recovered
# Satisfaction                  4
# Name: 0, dtype: object

# %%
df.iloc[5]["Condition"] # iloc - Index Location of 5th index condition is provided
# Out:
# 'Hypertension'

# %%
df.iloc[1:4]    # iloc - Index Location of 1 to 3rd index rows are provided
# Out:
#    Patient_ID  Age  Gender      Condition               Procedure   Cost  \
# 1           2   60    Male       Diabetes         Insulin Therapy   2000
# 2           3   32  Female  Fractured Arm        X-Ray and Splint    500
# 3           4   75    Male         Stroke  CT Scan and Medication  10000
#
#    Length_of_Stay Readmission    Outcome  Satisfaction
# 1               3         Yes     Stable             3
# 2               1          No  Recovered             5
# 3               7         Yes     Stable             2

# %%
# Filters
df.head()
# Out:
#    Patient_ID  Age  Gender      Condition                 Procedure   Cost  \
# 0           1   45  Female  Heart Disease               Angioplasty  15000
# 1           2   60    Male       Diabetes           Insulin Therapy   2000
# 2           3   32  Female  Fractured Arm          X-Ray and Splint    500
# 3           4   75    Male         Stroke    CT Scan and Medication  10000
# 4           5   50  Female         Cancer  Surgery and Chemotherapy  25000
#
#    Length_of_Stay Readmission    Outcome  Satisfaction
# 0               5          No  Recovered             4
# 1               3         Yes     Stable             3
# 2               1          No  Recovered             5
# 3               7         Yes     Stable             2
# 4              10          No  Recovered             4

# %%
df[df["Condition"] == "Fractured Arm"] # Filters the specific datas only
# Only Fractured Arm is shown
# Out:
#      Patient_ID  Age  Gender      Condition         Procedure  Cost  \
# 2             3   32  Female  Fractured Arm  X-Ray and Splint   500
# 17           18   35  Female  Fractured Arm  X-Ray and Splint   500
# 32           33   30  Female  Fractured Arm  X-Ray and Splint   500
# 47           48   35  Female  Fractured Arm  X-Ray and Splint   500
# 61           63   30  Female  Fractured Arm  X-Ray and Splint   500
# ..          ...  ...     ...            ...               ...   ...
# 917         933   30  Female  Fractured Arm  X-Ray and Splint   500
# 932         948   35  Female  Fractured Arm  X-Ray and Splint   500
# 947         963   30  Female  Fractured Arm  X-Ray and Splint   500
# 961         978   35  Female  Fractured Arm  X-Ray and Splint   500
# 976         993   30  Female  Fractured Arm  X-Ray and Splint   500
#
#      Length_of_Stay Readmission    Outcome  Satisfaction
# 2                 1          No  Recovered             5
# ...

# %%
df[(df["Condition"] == "Fractured Arm") & (df["Age"] == 35)]
# Out:
#      Patient_ID  Age  Gender      Condition         Procedure  Cost  \
# 17           18   35  Female  Fractured Arm  X-Ray and Splint   500
# 47           48   35  Female  Fractured Arm  X-Ray and Splint   500
# 76           78   35  Female  Fractured Arm  X-Ray and Splint   500
# 106         108   35  Female  Fractured Arm  X-Ray and Splint   500
# 135         138   35  Female  Fractured Arm  X-Ray and Splint   500
# 165         168   35  Female  Fractured Arm  X-Ray and Splint   500
# 194         198   35  Female  Fractured Arm  X-Ray and Splint   500
# 224         228   35  Female  Fractured Arm  X-Ray and Splint   500
# 253         258   35  Female  Fractured Arm  X-Ray and Splint   500
# 283         288   35  Female  Fractured Arm  X-Ray and Splint   500
# 312         318   35  Female  Fractured Arm  X-Ray and Splint   500
# 342         348   35  Female  Fractured Arm  X-Ray and Splint   500
# 371         378   35  Female  Fractured Arm  X-Ray and Splint   500
# ...

# %%
# Total number of people whose COndition was Fractured Arm and of aged 35
len(df[(df["Condition"] == "Fractured Arm") & (df["Age"] == 35)])
# Ther were 33 people who were have Fractured Arm and of 35 years old
# Out:
# 33

# %%
len(df[df["Condition"] == "Headach"])
# Out:
# 0

# %%
df["Condition"]
# Out:
# 0          Heart Disease
# 1               Diabetes
# 2          Fractured Arm
# 3                 Stroke
# 4                 Cancer
#              ...
# 979         Hypertension
# 980         Appendicitis
# 981        Fractured Leg
# 982         Heart Attack
# 983    Allergic Reaction
# Name: Condition, Length: 984, dtype: str

# %%
df[df["Condition"] == "Diabetes"]
# Out:
#      Patient_ID  Age Gender Condition        Procedure  Cost  Length_of_Stay  \
# 1             2   60   Male  Diabetes  Insulin Therapy  2000               3
# 16           17   62   Male  Diabetes  Insulin Therapy  2000               4
# 31           32   65   Male  Diabetes  Insulin Therapy  2000               5
# 46           47   62   Male  Diabetes  Insulin Therapy  2000               6
# 60           62   65   Male  Diabetes  Insulin Therapy  2000               7
# ..          ...  ...    ...       ...              ...   ...             ...
# 916         932   65   Male  Diabetes  Insulin Therapy  2000              65
# 931         947   62   Male  Diabetes  Insulin Therapy  2000              66
# 946         962   65   Male  Diabetes  Insulin Therapy  2000              67
# 960         977   62   Male  Diabetes  Insulin Therapy  2000              68
# 975         992   65   Male  Diabetes  Insulin Therapy  2000              69
#
#     Readmission Outcome  Satisfaction
# ...

# %%
len(df[df["Condition"] == "Diabetes"])
# Out:
# 65

# %%
# len(df[(df["Condition"] == "Diabetes"]) & (df["Procedure"] == "Therapy"))

len(df[(df["Condition"] == "Diabetes") | (df["Satisfaction"] == 3)]) # OR operator (|)
# Out:
# 294

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender      Condition                 Procedure   Cost  \
# 0           1   45  Female  Heart Disease               Angioplasty  15000
# 1           2   60    Male       Diabetes           Insulin Therapy   2000
# 2           3   32  Female  Fractured Arm          X-Ray and Splint    500
# 3           4   75    Male         Stroke    CT Scan and Medication  10000
# 4           5   50  Female         Cancer  Surgery and Chemotherapy  25000
#
#    Length_of_Stay Readmission    Outcome  Satisfaction
# 0               5          No  Recovered             4
# 1               3         Yes     Stable             3
# 2               1          No  Recovered             5
# 3               7         Yes     Stable             2
# 4              10          No  Recovered             4

# %%
df[df["Cost"] > 20000] # Greater than operator >
# Out:
#      Patient_ID  Age  Gender Condition                 Procedure   Cost  \
# 4             5   50  Female    Cancer  Surgery and Chemotherapy  25000
# 19           20   53  Female    Cancer  Surgery and Chemotherapy  25000
# 34           35   55  Female    Cancer  Surgery and Chemotherapy  25000
# 49           50   53  Female    Cancer  Surgery and Chemotherapy  25000
# 63           65   55  Female    Cancer  Surgery and Chemotherapy  25000
# ..          ...  ...     ...       ...                       ...    ...
# 919         935   55  Female    Cancer  Surgery and Chemotherapy  25000
# 934         950   53  Female    Cancer  Surgery and Chemotherapy  25000
# 949         965   55  Female    Cancer  Surgery and Chemotherapy  25000
# 963         980   53  Female    Cancer  Surgery and Chemotherapy  25000
# 978         995   55  Female    Cancer  Surgery and Chemotherapy  25000
#
#      Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
len(df[df["Cost"] > 20000])
# Out:
# 66

# %%
df[df["Condition"].str.startswith("A")]
# Out:
#      Patient_ID  Age  Gender          Condition              Procedure  Cost  \
# 6             7   55  Female       Appendicitis           Appendectomy  8000
# 9            10   25    Male  Allergic Reaction  Epinephrine Injection   100
# 21           22   60  Female       Appendicitis           Appendectomy  8000
# 24           25   28    Male  Allergic Reaction  Epinephrine Injection   100
# 36           37   45  Female       Appendicitis           Appendectomy  8000
# ..          ...  ...     ...                ...                    ...   ...
# 953         970   25    Male  Allergic Reaction  Epinephrine Injection   100
# 965         982   60  Female       Appendicitis           Appendectomy  8000
# 968         985   28    Male  Allergic Reaction  Epinephrine Injection   100
# 980         997   45  Female       Appendicitis           Appendectomy  8000
# 983        1000   25    Male  Allergic Reaction  Epinephrine Injection   100
#
# ...

# %%
df[df["Condition"].str.startswith("A")]
# Out:
#      Patient_ID  Age  Gender          Condition              Procedure  Cost  \
# 6             7   55  Female       Appendicitis           Appendectomy  8000
# 9            10   25    Male  Allergic Reaction  Epinephrine Injection   100
# 21           22   60  Female       Appendicitis           Appendectomy  8000
# 24           25   28    Male  Allergic Reaction  Epinephrine Injection   100
# 36           37   45  Female       Appendicitis           Appendectomy  8000
# ..          ...  ...     ...                ...                    ...   ...
# 953         970   25    Male  Allergic Reaction  Epinephrine Injection   100
# 965         982   60  Female       Appendicitis           Appendectomy  8000
# 968         985   28    Male  Allergic Reaction  Epinephrine Injection   100
# 980         997   45  Female       Appendicitis           Appendectomy  8000
# 983        1000   25    Male  Allergic Reaction  Epinephrine Injection   100
#
# ...

# %%
df[(df["Condition"].str.startswith("A")) & (df["Condition"].str.endswith("s"))]
# Out:
#      Patient_ID  Age  Gender     Condition     Procedure  Cost  \
# 6             7   55  Female  Appendicitis  Appendectomy  8000
# 21           22   60  Female  Appendicitis  Appendectomy  8000
# 36           37   45  Female  Appendicitis  Appendectomy  8000
# 51           52   60  Female  Appendicitis  Appendectomy  8000
# 65           67   45  Female  Appendicitis  Appendectomy  8000
# ..          ...  ...     ...           ...           ...   ...
# 906         922   60  Female  Appendicitis  Appendectomy  8000
# 921         937   45  Female  Appendicitis  Appendectomy  8000
# 936         952   60  Female  Appendicitis  Appendectomy  8000
# 965         982   60  Female  Appendicitis  Appendectomy  8000
# 980         997   45  Female  Appendicitis  Appendectomy  8000
#
#      Length_of_Stay Readmission    Outcome  Satisfaction
# 6                 4          No  Recovered             3
# 21                5         Yes  Recovered             3
# ...

# %%
df[df["Condition"].isin(["Diabetes","Appendicitis","Allergic Reaction"])]   # isin operator
# Out:
#      Patient_ID  Age  Gender          Condition              Procedure  Cost  \
# 1             2   60    Male           Diabetes        Insulin Therapy  2000
# 6             7   55  Female       Appendicitis           Appendectomy  8000
# 9            10   25    Male  Allergic Reaction  Epinephrine Injection   100
# 16           17   62    Male           Diabetes        Insulin Therapy  2000
# 21           22   60  Female       Appendicitis           Appendectomy  8000
# ..          ...  ...     ...                ...                    ...   ...
# 965         982   60  Female       Appendicitis           Appendectomy  8000
# 968         985   28    Male  Allergic Reaction  Epinephrine Injection   100
# 975         992   65    Male           Diabetes        Insulin Therapy  2000
# 980         997   45  Female       Appendicitis           Appendectomy  8000
# 983        1000   25    Male  Allergic Reaction  Epinephrine Injection   100
#
# ...

# %%
df[~df["Procedure"].isin(["Angioplasty","X-Ray and Splint","Medication and Counseling","Surgery and Chemotherapy"])]   # ~isin operator
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 1             2   60    Male           Diabetes            Insulin Therapy
# 3             4   75    Male             Stroke     CT Scan and Medication
# 6             7   55  Female       Appendicitis               Appendectomy
# 7             8   40    Male      Fractured Leg  Cast and Physical Therapy
# 8             9   70  Female       Heart Attack    Cardiac Catheterization
# ..          ...  ...     ...                ...                        ...
# 977         994   70    Male             Stroke     CT Scan and Medication
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
# Updating Data

# %%
df.loc[4]   # loc - locate accessing 4th data
# Out:
# Patient_ID                               5
# Age                                     50
# Gender                              Female
# Condition                           Cancer
# Procedure         Surgery and Chemotherapy
# Cost                                 25000
# Length_of_Stay                          10
# Readmission                             No
# Outcome                          Recovered
# Satisfaction                             4
# Product                                NaN
# Name: 4, dtype: object

# %%
df.loc[df["Condition"] == "Diabetes", "Fee"] = "Fee"

# %%
df.drop("Product", axis=1)
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction  Fee
# ...

# %%
df.drop("Fee", axis=1, inplace=True)

# %%
df
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
# ...

# %%
# Delete
df.drop("Product", axis=1, inplace=True)

# %%
df
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
df["Outcome"] = df["Outcome"].str.upper()   # str.upper() method changes entire column into upper case

# %%
df["Outcome"]
# Out:
# 0      RECOVERED
# 1         STABLE
# 2      RECOVERED
# 3         STABLE
# 4      RECOVERED
#          ...
# 979       STABLE
# 980    RECOVERED
# 981    RECOVERED
# 982       STABLE
# 983    RECOVERED
# Name: Outcome, Length: 984, dtype: str

# %%
df
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
df.dropna()
# Out:
#      Patient_ID  Age  Gender          Condition                  Procedure  \
# 0             1   45  Female      Heart Disease                Angioplasty
# 1             2   60    Male           Diabetes            Insulin Therapy
# 2             3   32  Female      Fractured Arm           X-Ray and Splint
# 3             4   75    Male             Stroke     CT Scan and Medication
# 4             5   50  Female             Cancer   Surgery and Chemotherapy
# ..          ...  ...     ...                ...                        ...
# 979         996   68    Male       Hypertension  Medication and Counseling
# 980         997   45  Female       Appendicitis               Appendectomy
# 981         998   40    Male      Fractured Leg  Cast and Physical Therapy
# 982         999   78  Female       Heart Attack    Cardiac Catheterization
# 983        1000   25    Male  Allergic Reaction      Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
df["Condition"].value_counts()  # value_counts() method counts entire number data of the column
# Out:
# Condition
# Fractured Leg            67
# Heart Attack             67
# Fractured Arm            66
# Stroke                   66
# Cancer                   66
# Hypertension             66
# Appendicitis             66
# Allergic Reaction        66
# Heart Disease            65
# Diabetes                 65
# Respiratory Infection    65
# Prostate Cancer          65
# Childbirth               65
# Kidney Stones            65
# Osteoarthritis           64
# Name: count, dtype: int64

# %%
df.groupby("Condition")["Cost"].sum()
# Out:
# Condition
# Allergic Reaction           6600
# Appendicitis              528000
# Cancer                   1650000
# Childbirth                780000
# Diabetes                  130000
# Fractured Arm              33000
# Fractured Leg             201000
# Heart Attack             1206000
# Heart Disease             975000
# Hypertension               66000
# Kidney Stones             390000
# Osteoarthritis            256000
# Prostate Cancer          1300000
# Respiratory Infection      52000
# Stroke                    660000
# Name: Cost, dtype: int64

# %%
df.sort_values("Cost", ascending=False)
# Out:
#      Patient_ID  Age  Gender          Condition                 Procedure  \
# 949         965   55  Female             Cancer  Surgery and Chemotherapy
# 4             5   50  Female             Cancer  Surgery and Chemotherapy
# 358         365   55  Female             Cancer  Surgery and Chemotherapy
# 211         215   55  Female             Cancer  Surgery and Chemotherapy
# 934         950   53  Female             Cancer  Surgery and Chemotherapy
# ..          ...  ...     ...                ...                       ...
# 658         670   25    Male  Allergic Reaction     Epinephrine Injection
# 39           40   25    Male  Allergic Reaction     Epinephrine Injection
# 349         355   28    Male  Allergic Reaction     Epinephrine Injection
# 24           25   28    Male  Allergic Reaction     Epinephrine Injection
# 9            10   25    Male  Allergic Reaction     Epinephrine Injection
#
#       Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# ...

# %%
df.to_csv("New_hospital.csv", index= False)
