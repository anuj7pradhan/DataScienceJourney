# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name" : ["cat","dog","fish","crocodile","monkey"]
})
df
# Out:
#         Name
# 0        cat
# 1        dog
# 2       fish
# 3  crocodile
# 4     monkey

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["en_name"] = le.fit_transform(df["Name"])

# %%
df
# Out:
#         Name  en_name
# 0        cat        0
# 1        dog        2
# 2       fish        3
# 3  crocodile        1
# 4     monkey        4

# %%
data = pd.read_csv("loan.csv")

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# Label Encoding on loan  dataset Education

edu_label = LabelEncoder()
edu_label.fit(data["Education"])
# Out:
# LabelEncoder()

# %%
data["Education"]=edu_label.transform(data["Education"])

# %%
data["Education"].unique()
# Out:
# array([0, 1])

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents  Education Self_Employed  \
# 0    LP001002    Male      No          0          0            No
# 1    LP001003    Male     Yes          1          0            No
# 2    LP001005    Male     Yes          0          0           Yes
# 3    LP001006    Male     Yes          0          1            No
# 4    LP001008    Male      No          0          0            No
# ..        ...     ...     ...        ...        ...           ...
# 609  LP002978  Female      No          0          0            No
# 610  LP002979    Male     Yes         3+          0            No
# 611  LP002983    Male     Yes          1          0            No
# 612  LP002984    Male     Yes          2          0            No
# 613  LP002990  Female      No          0          0           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
pa_label = LabelEncoder()
pa_label.fit(data["Property_Area"])
# Out:
# LabelEncoder()

# %%
data["Property_Area"] = pa_label.transform(data["Property_Area"])

# %%
data["Property_Area"]
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 609    0
# 610    0
# 611    2
# 612    2
# 613    1
# Name: Property_Area, Length: 614, dtype: int64

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents  Education Self_Employed  \
# 0    LP001002    Male      No          0          0            No
# 1    LP001003    Male     Yes          1          0            No
# 2    LP001005    Male     Yes          0          0           Yes
# 3    LP001006    Male     Yes          0          1            No
# 4    LP001008    Male      No          0          0            No
# ..        ...     ...     ...        ...        ...           ...
# 609  LP002978  Female      No          0          0            No
# 610  LP002979    Male     Yes         3+          0            No
# 611  LP002983    Male     Yes          1          0            No
# 612  LP002984    Male     Yes          2          0            No
# 613  LP002990  Female      No          0          0           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents  Education Self_Employed  \
# 0  LP001002   Male      No          0          0            No
# 1  LP001003   Male     Yes          1          0            No
# 2  LP001005   Male     Yes          0          0           Yes
# 3  LP001006   Male     Yes          0          1            No
# 4  LP001008   Male      No          0          0            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 0             1.0              2           Y
# 1             1.0              0           N
# ...

# %%
data["Property_Area"].unique()
# Out:
# array([2, 0, 1])

# %%
https://youtu.be/gDZ6czwuQ18
7 12 7
