# %%
input("Enter your name:")
# Out:
# Enter your name: anuj
# 'anuj'

# %%
name = input("Enter your name")
# Out:
# Enter your name anuj

# %%
print ("Your", name)
# Out:
# Your anuj

# %%
country= "Nepal"

# %%
print("your name is ",name, "and Your country name is", country)
# Out:
# your name is  anuj and Your country name is Nepal
